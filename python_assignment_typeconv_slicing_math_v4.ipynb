# %% [markdown]
# # Python Assignment: Type Conversion, String Slicing & Mathematical Expressions
#
# **Instructions:**
# - Write your answer in the code cell directly below each question.
# - Use `print()` to display all results.
# - Do not change the order of the cells.

# %% [markdown]
# ## Section 1: Type Conversion

# %% [markdown]
# ### Question 1
# Given `s = "123"`, convert it to an integer using `int()` and print the result along with its type.

# %%
s = "123"
result = int(s)
print(result, type(result))

# %% [markdown]
# ### Question 2
# Given `s = "12.5"`, convert it to a float using `float()` and print the result along with its type.

# %%
s = "12.5"
result = float(s)
print(result, type(result))

# %% [markdown]
# ### Question 3
# Given `num = 100`, convert it to a string using `str()` and print the result along with its type.

# %%
num = 100
result = str(num)
print(result, type(result))

# %% [markdown]
# ### Question 4
# Given `f = 9.99`, convert it to an integer using `int()` and print the result. Notice what happens to the decimal part.

# %%
f = 9.99
result = int(f)
print(result)

# %% [markdown]
# ### Question 5
# Given `b = True`, convert it to a string using `str()` and print the result along with its type.

# %%
b = True
result = str(b)
print(result, type(result))

# %% [markdown]
# ### Question 6
# Given `n = 0`, convert it to a string using `str()`, then check the boolean value of that string using `bool()`. Print both results.

# %%
n = 0
s = str(n)
print(s, bool(s))

# %% [markdown]
# ### Question 7
# Take a number as input from the user using `input()`, convert it to an integer, and print double the value.

# %%
num = int(input("Enter a number: "))
print(num * 2)

# %% [markdown]
# ### Question 8
# Take two numbers as input from the user using `input()`, convert both to floats, and print their sum.

# %%
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))
print(a + b)

# %% [markdown]
# ### Question 9
# Given `x = "100"` and `y = "25"`, convert both to integers and print their product.

# %%
x = "100"
y = "25"
print(int(x) * int(y))

# %% [markdown]
# ### Question 10
# Given `f = 15.0`, convert it to an integer and then convert that result back to a float. Print the final value and its type.

# %%
f = 15.0
result = float(int(f))
print(result, type(result))

# %% [markdown]
# ## Section 2: String Slicing (using [m:n] and [-n])

# %% [markdown]
# ### Question 11
# Given `s = "Python Programming"`, extract and print the first 6 characters using slicing `[0:6]`.

# %%
s = "Python Programming"
print(s[0:6])

# %% [markdown]
# ### Question 12
# Given `s = "Python Programming"`, extract and print the last 11 characters using negative slicing `[-11:]`.

# %%
s = "Python Programming"
print(s[-11:])

# %% [markdown]
# ### Question 13
# Given `s = "Hello World"`, extract and print just `"World"` using negative slicing `[-5:]`.

# %%
s = "Hello World"
print(s[-5:])

# %% [markdown]
# ### Question 14
# Given `s = "0123456789"`, extract and print the substring from index 2 to index 7 using `[2:7]`.

# %%
s = "0123456789"
print(s[2:7])

# %% [markdown]
# ### Question 15
# Given `s = "Python"`, print the last character of the string using `[-1]`.

# %%
s = "Python"
print(s[-1])

# %% [markdown]
# ### Question 16
# Given `s = "Data Science"`, extract and print just `"Data"` using slicing `[0:4]`.

# %%
s = "Data Science"
print(s[0:4])

# %% [markdown]
# ### Question 17
# Given `s = "MachineLearning"`, print the first 7 characters and the remaining characters separately using slicing.

# %%
s = "MachineLearning"
print(s[0:7])
print(s[7:])

# %% [markdown]
# ### Question 18
# Given `s = "Hello, World!"`, extract and print just `"World"` using slicing `[7:12]`.

# %%
s = "Hello, World!"
print(s[7:12])

# %% [markdown]
# ### Question 19
# Given `s = "abcdefgh"`, print the last 3 characters of the string using `[-3:]`.

# %%
s = "abcdefgh"
print(s[-3:])

# %% [markdown]
# ### Question 20
# Given `s = "Programming"`, extract and print the middle part `"gram"` using slicing `[3:7]`.

# %%
s = "Programming"
print(s[3:7])

# %% [markdown]
# ## Section 3: Mathematical Expressions (using the math library)

# %% [markdown]
# ### Question 21
# Using the `math` library, calculate and print the square root of `81`.

# %%
import math
print(math.sqrt(81))

# %% [markdown]
# ### Question 22
# Using the `math` library, calculate `math.factorial(6)` and print the result.

# %%
import math
print(math.factorial(6))

# %% [markdown]
# ### Question 23
# Given `a = 2` and `b = 10`, calculate `a` raised to the power `b` using both `**` and `math.pow()`, and print both results.

# %%
import math
a = 2
b = 10
print(a ** b)
print(math.pow(a, b))

# %% [markdown]
# ### Question 24
# Using the `math` library, calculate `math.log(100, 10)` and print it.

# %%
import math
print(math.log(100, 10))

# %% [markdown]
# ### Question 25
# Using `math.pi` and `math.e`, print the sum of the two constants rounded to 4 decimal places.

# %%
import math
print(round(math.pi + math.e, 4))

# %% [markdown]
# ### Question 26
# Given `radius = 4.5`, calculate the area of a circle using `math.pi * radius ** 2` and print it rounded to 2 decimals.

# %%
import math
radius = 4.5
area = math.pi * radius ** 2
print(round(area, 2))

# %% [markdown]
# ### Question 27
# Given `x = 7.3` and `y = 7.8`, print the results of `math.ceil()` and `math.floor()` applied to both numbers.

# %%
import math
x = 7.3
y = 7.8
print(math.ceil(x), math.floor(x))
print(math.ceil(y), math.floor(y))

# %% [markdown]
# ### Question 28
# A right-angled triangle has legs `a = 6` and `b = 8`. Using `math.sqrt()`, calculate and print the length of the hypotenuse.

# %%
import math
a = 6
b = 8
hypotenuse = math.sqrt(a ** 2 + b ** 2)
print(hypotenuse)

# %% [markdown]
# ### Question 29
# Evaluate and print the result of the expression `10 % 3 + 5 ** 2 - math.floor(7.8)`.

# %%
import math
print(10 % 3 + 5 ** 2 - math.floor(7.8))

# %% [markdown]
# ### Question 30
# Given `r = 3`, calculate and print the volume of a sphere using the formula `(4/3) * math.pi * r ** 3`, rounded to 2 decimals.

# %%
import math
r = 3
volume = (4 / 3) * math.pi * r ** 3
print(round(volume, 2))

# %% [markdown]
# ## Section 4: Long Mathematical Expressions (Evaluate and Verify)

# %% [markdown]
# ### Question 31
# Evaluate the expression below and print the result. *(Hint: use `sqrt` for square root.)*
#
# $$(5 + 3 \times 2)^2 - \sqrt{49} + \frac{10}{2}$$
#
# Your answer should come out to **119.0**.

# %%
import math
result = (5 + 3 * 2) ** 2 - math.sqrt(49) + 10 / 2
print(result)

# %% [markdown]
# ### Question 32
# Evaluate the expression below and print the result. *(Hint: use `pow` or `**` for powers, and `factorial` for `!`.)*
#
# $$2^5 + 4! - \sqrt{144} \times 2$$
#
# Your answer should come out to **32.0**.

# %%
import math
result = 2 ** 5 + math.factorial(4) - math.sqrt(144) * 2
print(result)

# %% [markdown]
# ### Question 33
# Evaluate the expression below and print the result rounded to 2 decimals. *(Hint: `pi` and `e` are constants in the math library, and `floor` rounds down.)*
#
# $$(\pi \times 5^2) + e^2 - \lfloor 15.9 \rfloor$$
#
# Your answer should come out to approximately **70.93**.

# %%
import math
result = (math.pi * 5 ** 2) + math.e ** 2 - math.floor(15.9)
print(round(result, 2))

# %% [markdown]
# ### Question 34
# Evaluate the expression below and print the result. *(Hint: `ceil` rounds up, `floor` rounds down, `%` gives the remainder.)*
#
# $$\lceil 23.4 \rceil + \lfloor 10.9 \rfloor \times \sqrt{16} - (7 \bmod 3)$$
#
# Your answer should come out to **63.0**.

# %%
import math
result = math.ceil(23.4) + math.floor(10.9) * math.sqrt(16) - (7 % 3)
print(result)

# %% [markdown]
# ### Question 35
# Evaluate the expression below and print the result. *(Hint: `log(x, base)` computes the logarithm.)*
#
# $$\frac{(10 + 20) \times 3 - \sqrt{64}}{2} + \log_{10}(1000)$$
#
# Your answer should come out to **44.0**.

# %%
import math
result = ((10 + 20) * 3 - math.sqrt(64)) / 2 + math.log(1000, 10)
print(result)

# %% [markdown]
# ### Question 36
# Evaluate the expression below and print the result rounded to 2 decimals.
#
# $$3^3 + 3! - 2\pi + \lfloor 9.99 \rfloor$$
#
# Your answer should come out to approximately **35.72**.

# %%
import math
result = 3 ** 3 + math.factorial(3) - 2 * math.pi + math.floor(9.99)
print(round(result, 2))

# %% [markdown]
# ### Question 37
# Evaluate the expression below and print the result rounded to 3 decimals.
#
# $$\frac{100 - \sqrt{81}}{\lceil 4.2 \rceil + \lfloor 3.9 \rfloor}$$
#
# Your answer should come out to approximately **11.375**.

# %%
import math
result = (100 - math.sqrt(81)) / (math.ceil(4.2) + math.floor(3.9))
print(round(result, 3))

# %% [markdown]
# ### Question 38
# Evaluate the expression below and print the result rounded to 2 decimals.
#
# $$\sqrt{5!} + 2^4 - \pi$$
#
# Your answer should come out to approximately **23.81**.

# %%
import math
result = math.sqrt(math.factorial(5)) + 2 ** 4 - math.pi
print(round(result, 2))

# %% [markdown]
# ## Section 5: Exponential, Trigonometric & Logarithmic Expressions

# %% [markdown]
# ### Question 39
# Evaluate the expression below for `x = 1, 2, 3, 4, 5` and print all five results. *(Hint: use `exp` for $e^x$, `sin` for sine, and `log` for the natural logarithm.)*
#
# $$f(x) = e^x \times \sin(x) + \ln(x + 1) - \sqrt{x}$$
#
# Your answers should come out to approximately:
# - x=1: **1.98**
# - x=2: **6.40**
# - x=3: **2.49**
# - x=4: **-41.71**
# - x=5: **-142.76**

# %%
import math

x = 1
print(math.exp(x) + math.sqrt(x))

x = 2
print(math.exp(x) + math.sqrt(x))

x = 3
print(math.exp(x) + math.sqrt(x))

x = 4
print(math.exp(x) + math.sqrt(x))

x = 5
print(math.exp(x) + math.sqrt(x))

# %% [markdown]
# ### Question 40
# Evaluate the expression below for `x = 1, 2, 3, 4, 5` and print all five results. *(Hint: use `sin`, `cos`, `log10` for base-10 log, and `exp`.)*
#
# $$f(x) = \sin^2(x) + \cos^2(x) \times \log_{10}(x + 1) + e^{x/2}$$
#
# Your answers should come out to approximately:
# - x=1: **2.44**
# - x=2: **3.63**
# - x=3: **5.09**
# - x=4: **8.26**
# - x=5: **13.16**

# %%
import math

x = 1
print(math.sin(x) + math.cos(x))

x = 2
print(math.sin(x) + math.cos(x))

x = 3
print(math.sin(x) + math.cos(x))

x = 4
print(math.sin(x) + math.cos(x))

x = 5
print(math.sin(x) + math.cos(x))

# %% [markdown]
# ### Question 41
# Evaluate the expression below for `x = 1, 2, 3, 4, 5` and print all five results. *(Hint: use `log(x, 2)` for base-2 log, `tan` for tangent, and `exp(-x)` for $e^{-x}$.)*
#
# $$f(x) = \log_2(x + 1) + \tan(x) - e^{-x} + x^2$$
#
# Your answers should come out to approximately:
# - x=1: **3.19**
# - x=2: **3.26**
# - x=3: **10.81**
# - x=4: **19.46**
# - x=5: **24.20**

# %%
import math

x = 1
print(math.tan(x))

x = 2
print(math.tan(x))

x = 3
print(math.tan(x))

x = 4
print(math.tan(x))

x = 5
print(math.tan(x))

# %% [markdown]
# ### Question 42
# Evaluate the expression below for `x = 1, 2, 3` and print all three results. *(Hint: combine `exp` and `sin` with ordinary arithmetic like multiplication and division.)*
#
# $$f(x) = 2e^x + 3\sin(x) - \ln(x + 2) + \frac{x^2}{2}$$
#
# Your answers should come out to approximately:
# - x=1: **7.36**
# - x=2: **18.12**
# - x=3: **43.49**

# %%
import math

x = 1
print(math.log(x + 1))

x = 2
print(math.log(x + 1))

x = 3
print(math.log(x + 1))

x = 4
print(math.log(x + 1))

x = 5
print(math.log(x + 1))

# %% [markdown]
# ### Question 43
# Evaluate the expression below for `x = 1, 2, 3` and print all three results. *(Hint: use `exp(x/2)` for $e^{x/2}$, `cos` for cosine, and `log10` for base-10 log.)*
#
# $$f(x) = e^{x/2} \times \cos(x) + \log_{10}(x + 5) - x^3 + 4x$$
#
# Your answers should come out to approximately:
# - x=1: **4.67**
# - x=2: **-0.29**
# - x=3: **-18.53**

# %%
import math

x = 1
print(math.exp(x) - math.log(x + 1))

x = 2
print(math.exp(x) - math.log(x + 1))

x = 3
print(math.exp(x) - math.log(x + 1))

x = 4
print(math.exp(x) - math.log(x + 1))

x = 5
print(math.exp(x) - math.log(x + 1))

# %% [markdown]
# ### Question 44
# Evaluate the expression below for `x = 1, 2, 3` and print all three results. *(Hint: this one combines `exp`, `log`, and `sin` inside a single fraction.)*
#
# $$f(x) = \frac{e^x + \ln(x + 1)}{\sin(x) + 2} - x^2 + 7$$
#
# Your answers should come out to approximately:
# - x=1: **7.20**
# - x=2: **5.92**
# - x=3: **8.03**

# %%
import math

x = 1
print(math.sin(x) ** 2 + math.cos(x) ** 2)

x = 2
print(math.sin(x) ** 2 + math.cos(x) ** 2)

x = 3
print(math.sin(x) ** 2 + math.cos(x) ** 2)

x = 4
print(math.sin(x) ** 2 + math.cos(x) ** 2)

x = 5
print(math.sin(x) ** 2 + math.cos(x) ** 2)
